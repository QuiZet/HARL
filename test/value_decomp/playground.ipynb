# %% [markdown]
# ### Decomposed Critic

# %% [markdown]
# MD block for decomposition math

# %%
# Import necessary modules
import sys
import os
import torch

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'using device: {device}')

# Add the directory containing your modules to the Python path (if needed)
module_path = os.path.abspath(os.path.join(''))
if module_path not in sys.path:
    sys.path.append(module_path)

# Import the train function
from train import train

# Run training with the standard critic
print("Training with standard critic...")
train(use_decomposed_critic=False)

# Run training with the decomposed critic (currently empty)
print("\nTraining with decomposed critic (to be implemented)...")
train(use_decomposed_critic=True)
# Out:
# using device: cuda
# Training with standard critic...
#
# Timestep: 100
# Adversary 0:
#   Average Reward: 400.00
#   Average Actor Loss: -2.8133
#   Average Critic Loss: 53.3567
#   Average Entropy: 1.1762
# Adversary 1:
#   Average Reward: 400.00
#   Average Actor Loss: -4.1098
#   Average Critic Loss: 75.6783
#   Average Entropy: 0.9319
# Adversary 2:
#   Average Reward: 400.00
#   Average Actor Loss: -1.6761
#   Average Critic Loss: 45.0471
#   Average Entropy: 1.4825
#
# Timestep: 200
# Adversary 0:
#   Average Reward: 385.00
#   Average Actor Loss: -13.6333
#   Average Critic Loss: 374.8622
#   Average Entropy: 0.4156
# Adversary 1:
#   Average Reward: 385.00
#   Average Actor Loss: -25.0529
#   Average Critic Loss: 1113.3703
#   Average Entropy: 0.0921
# Adversary 2:
#   Average Reward: 385.00
#   Average Actor Loss: 1.1646
#   Average Critic Loss: 27.0914
#   Average Entropy: 1.2292
#
# Timestep: 300
# Adversary 0:
#   Average Reward: 356.67
#   Average Actor Loss: -75.0983
# ...
