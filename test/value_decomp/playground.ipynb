# %% [markdown]
# ### Decomposed Critic

# %% [markdown]
# MD block for decomposition math

# %%
import random
import numpy as np
import torch
import os

def set_deterministic():
    print('set deterministic')
    # Activate deterministic algorithms
    os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'  # Or ':16:8'
    torch.backends.cudnn.deterministic = True
    torch.use_deterministic_algorithms(True)
    torch.backends.cudnn.benchmark = False

def seed_everything(seed):
    print(f'seed_everything:{seed}')
    # Set random seeds for reproducibility
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)

# %%
# Import necessary modules
import sys
import os
import torch

# Add the directory containing your modules to the Python path (if needed)
module_path = os.path.abspath(os.path.join(''))
if module_path not in sys.path:
    sys.path.append(module_path)

# Set random seed for reproducibility
SEED = 42  
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
set_deterministic()
seed_everything(SEED)



# Ensure reproducibility when using CUDA
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)  # If using multi-GPU setups



# Import the train function
from train import train

# Run training with the standard critic
print("Training with standard critic...")
train(use_decomposed_critic=False)

# Run training with the decomposed critic (currently empty)
print("\nTraining with decomposed critic (to be implemented)...")
train(use_decomposed_critic=True)
# Out:
# set deterministic
# seed_everything:42
# using device: cuda
# Training with standard critic...
#
# Timestep: 100
# Adversary 0:
#   Average Reward: 360.00
#   Average Actor Loss: -1.5851
#   Average Critic Loss: 40.3065
#   Average Entropy: 1.5255
# Adversary 1:
#   Average Reward: 360.00
#   Average Actor Loss: -3.6923
#   Average Critic Loss: 61.4971
#   Average Entropy: 1.0846
# Adversary 2:
#   Average Reward: 360.00
#   Average Actor Loss: -2.4970
#   Average Critic Loss: 47.4581
#   Average Entropy: 1.3545
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 33
#      31 # Run training with the standard critic
#      32 print("Training with standard critic...")
# ---> 33 train(use_decomposed_critic=False)
#      35 # Run training with the decomposed critic (currently empty)
#      36 print("\nTraining with decomposed critic (to be implemented)...")
#
# File ~/HARL/test/value_decomp/train.py:130, in train(use_decomposed_critic)
#     128 surr1 = ratio * batch_advantages
#     129 surr2 = torch.clamp(ratio, 1.0 - CLIP_EPS, 1.0 + CLIP_EPS) * batch_advantages
# --> 130 actor_loss = -torch.min(surr1, surr2).mean()
#     132 # Critic loss
#     133 if use_decomposed_critic:
#     134     # Placeholder: Implement decomposed critic loss computation
#
# KeyboardInterrupt:
